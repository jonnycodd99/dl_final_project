# %%
import ee
import geemap
from tqdm import tqdm
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ee.Authenticate()
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
start_dates = ['2024-01-01']
end_dates = ['2024-02-29']
labels = ['24_01']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Function to mask clouds based on the QA60 band of Sentinel-2 SR data.
def maskS2clouds(image):
    qa = image.select('QA60')
    cloudBitMask = 1 << 10
    cirrusBitMask = 1 << 11
    
    mask = qa.bitwiseAnd(cloudBitMask).eq(0).And(qa.bitwiseAnd(cirrusBitMask).eq(0))
    
    return image.updateMask(mask).divide(10000)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# # Catalonia

# %%
output_folder = "catalonia_dl_final"
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
for i in tqdm(range(len(start_dates)), desc='Exporting images'):

    start_date = start_dates[i]
    end_date = end_dates[i]
    label = labels[i]


    # Load Sentinel-2 image collection.
    dataset = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED') \
    .filterDate(start_date, end_date) \
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20)) \
    .map(maskS2clouds) \
    .select(['B4', 'B3', 'B2', 'B8'])

    # Define the area of interest.
    geometry = ee.FeatureCollection('projects/ee-huijuanli/assets/random_squares_cat')

    # Select the first image from the collection.
    imageToExport = dataset.median() 

    # Get the list of features in the collection.
    features = geometry.getInfo()['features']

    # Loop through each feature and submit an export task.
    for index, feature in enumerate(features):
        featureGeometry = ee.Feature(feature).geometry()
        imageToExportClipped = imageToExport.clip(featureGeometry)
        
        task = ee.batch.Export.image.toDrive(
            image=imageToExportClipped,
            description=f'Sentinel2_Image_Export_{index}_{label}',
            scale=10,
            folder=f'{output_folder}',
            region=featureGeometry,
            fileFormat='GeoTIFF',
            crs='EPSG:25831', 
            formatOptions={
                'cloudOptimized': True
            }
        )
        task.start()
        print(f'Task for feature {index} started.')

    print('All export tasks initiated.')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Exporting images:   0%|          | 0/1 [00:00<?, ?it/s]
# Task for feature 0 started.
# Task for feature 1 started.
# Task for feature 2 started.
# Task for feature 3 started.
# Task for feature 4 started.
# Task for feature 5 started.
# Task for feature 6 started.
# Task for feature 7 started.
# Task for feature 8 started.
# Task for feature 9 started.
# Task for feature 10 started.
# Task for feature 11 started.
# Task for feature 12 started.
# Task for feature 13 started.
# Task for feature 14 started.
# Task for feature 15 started.
# Task for feature 16 started.
# Task for feature 17 started.
# Task for feature 18 started.
# Task for feature 19 started.
# Task for feature 20 started.
# Task for feature 21 started.
# Task for feature 22 started.
# Task for feature 23 started.
# Task for feature 24 started.
# Task for feature 25 started.
# Task for feature 26 started.
# Task for feature 27 started.
# Task for feature 28 started.
# Task for feature 29 started.
# Task for feature 30 started.
# Task for feature 31 started.
# Task for feature 32 started.
# Task for feature 33 started.
# Task for feature 34 started.
# Task for feature 35 started.
# Task for feature 36 started.
# Task for feature 37 started.
# Task for feature 38 started.
# Task for feature 39 started.
# Task for feature 40 started.
# Task for feature 41 started.
# Task for feature 42 started.
# Task for feature 43 started.
# Task for feature 44 started.
# Task for feature 45 started.
# Task for feature 46 started.
# Task for feature 47 started.
# Task for feature 48 started.
# Task for feature 49 started.
# Task for feature 50 started.
# Task for feature 51 started.
# Task for feature 52 started.
# Task for feature 53 started.
# Task for feature 54 started.
# Task for feature 55 started.
# Task for feature 56 started.
# Task for feature 57 started.
# Task for feature 58 started.
# Task for feature 59 started.
# Task for feature 60 started.
# Task for feature 61 started.
# Task for feature 62 started.
# Task for feature 63 started.
# Task for feature 64 started.
# Task for feature 65 started.
# Task for feature 66 started.
# Task for feature 67 started.
# Task for feature 68 started.
# Task for feature 69 started.
# Task for feature 70 started.
# Task for feature 71 started.
# Task for feature 72 started.
# Task for feature 73 started.
# Task for feature 74 started.
# Task for feature 75 started.
# Task for feature 76 started.
# Task for feature 77 started.
# Task for feature 78 started.
# Task for feature 79 started.
# Task for feature 80 started.
# Task for feature 81 started.
# Task for feature 82 started.
# Task for feature 83 started.
# Task for feature 84 started.
# Task for feature 85 started.
# Task for feature 86 started.
# Task for feature 87 started.
# Task for feature 88 started.
# Task for feature 89 started.
# Task for feature 90 started.
# Task for feature 91 started.
# Task for feature 92 started.
# Task for feature 93 started.
# Task for feature 94 started.
# Task for feature 95 started.
# Task for feature 96 started.
# Task for feature 97 started.
# Task for feature 98 started.
# Task for feature 99 started.
# Task for feature 100 started.
# Task for feature 101 started.
# Task for feature 102 started.
# Task for feature 103 started.
# Task for feature 104 started.
# Task for feature 105 started.
# Task for feature 106 started.
# Task for feature 107 started.
# Task for feature 108 started.
# Task for feature 109 started.
# Task for feature 110 started.
# Task for feature 111 started.
# Task for feature 112 started.
# Task for feature 113 started.
# Task for feature 114 started.
# Task for feature 115 started.
# Task for feature 116 started.
# Task for feature 117 started.
# Task for feature 118 started.
# Task for feature 119 started.
# Task for feature 120 started.
# Task for feature 121 started.
# Task for feature 122 started.
# Task for feature 123 started.
# Task for feature 124 started.
# Task for feature 125 started.
# Task for feature 126 started.
# Task for feature 127 started.
# Task for feature 128 started.
# Task for feature 129 started.
# Task for feature 130 started.
# Task for feature 131 started.
# Task for feature 132 started.
# Task for feature 133 started.
# Task for feature 134 started.
# Task for feature 135 started.
# Task for feature 136 started.
# Task for feature 137 started.
# Task for feature 138 started.
# Task for feature 139 started.
# Task for feature 140 started.
# Task for feature 141 started.
# Task for feature 142 started.
# Task for feature 143 started.
# Task for feature 144 started.
# Task for feature 145 started.
# Task for feature 146 started.
# Task for feature 147 started.
# Task for feature 148 started.
# Task for feature 149 started.
# Task for feature 150 started.
# Task for feature 151 started.
# Task for feature 152 started.
# Task for feature 153 started.
# Task for feature 154 started.
# Task for feature 155 started.
# Task for feature 156 started.
# Task for feature 157 started.
# Task for feature 158 started.
# Task for feature 159 started.
# Task for feature 160 started.
# Task for feature 161 started.
# Task for feature 162 started.
# Task for feature 163 started.
# Task for feature 164 started.
# Task for feature 165 started.
# Task for feature 166 started.
# Task for feature 167 started.
# Task for feature 168 started.
# Task for feature 169 started.
# Task for feature 170 started.
# Task for feature 171 started.
# Task for feature 172 started.
# Task for feature 173 started.
# Task for feature 174 started.
# Task for feature 175 started.
# Task for feature 176 started.
# Task for feature 177 started.
# Task for feature 178 started.
# Task for feature 179 started.
# Task for feature 180 started.
# Task for feature 181 started.
# Task for feature 182 started.
# Task for feature 183 started.
# Task for feature 184 started.
# Task for feature 185 started.
# Task for feature 186 started.
# Task for feature 187 started.
# Task for feature 188 started.
# Task for feature 189 started.
# Task for feature 190 started.
# Task for feature 191 started.
# Task for feature 192 started.
# Task for feature 193 started.
# Task for feature 194 started.
# Task for feature 195 started.
# Task for feature 196 started.
# Task for feature 197 started.
# Task for feature 198 started.
# Task for feature 199 started.
# Task for feature 200 started.
# Task for feature 201 started.
# Task for feature 202 started.
# Task for feature 203 started.
# Task for feature 204 started.
# Task for feature 205 started.
# Task for feature 206 started.
# Task for feature 207 started.
# Task for feature 208 started.
# Task for feature 209 started.
# Task for feature 210 started.
# Task for feature 211 started.
# Task for feature 212 started.
# Task for feature 213 started.
# Task for feature 214 started.
# Task for feature 215 started.
# Task for feature 216 started.
# Task for feature 217 started.
# Task for feature 218 started.
# Task for feature 219 started.
# Task for feature 220 started.
# Task for feature 221 started.
# Task for feature 222 started.
# Task for feature 223 started.
# Task for feature 224 started.
# Task for feature 225 started.
# Task for feature 226 started.
# Task for feature 227 started.
# Task for feature 228 started.
# Task for feature 229 started.
# Task for feature 230 started.
# Task for feature 231 started.
# Task for feature 232 started.
# Task for feature 233 started.
# Task for feature 234 started.
# Task for feature 235 started.
# Task for feature 236 started.
# Task for feature 237 started.
# Task for feature 238 started.
# Task for feature 239 started.
# Task for feature 240 started.
# Task for feature 241 started.
# Task for feature 242 started.
# Task for feature 243 started.
# Task for feature 244 started.
# Task for feature 245 started.
# Task for feature 246 started.
# Task for feature 247 started.
# Task for feature 248 started.
# Task for feature 249 started.
# Task for feature 250 started.
# Task for feature 251 started.
# Task for feature 252 started.
# Task for feature 253 started.
# Task for feature 254 started.
# Task for feature 255 started.
# Task for feature 256 started.
# Task for feature 257 started.
# Task for feature 258 started.
# Task for feature 259 started.
# Task for feature 260 started.
# Task for feature 261 started.
# Task for feature 262 started.
# Task for feature 263 started.
# Task for feature 264 started.
# Task for feature 265 started.
# Task for feature 266 started.
# Task for feature 267 started.
# Task for feature 268 started.
# Task for feature 269 started.
# Task for feature 270 started.
# Task for feature 271 started.
# Task for feature 272 started.
# Task for feature 273 started.
# Task for feature 274 started.
# Task for feature 275 started.
# Task for feature 276 started.
# Task for feature 277 started.
# Task for feature 278 started.
# Task for feature 279 started.
# Task for feature 280 started.
# Task for feature 281 started.
# Task for feature 282 started.
# Task for feature 283 started.
# Task for feature 284 started.
# Task for feature 285 started.
# Task for feature 286 started.
# Task for feature 287 started.
# Task for feature 288 started.
# Task for feature 289 started.
# Task for feature 290 started.
# Task for feature 291 started.
# Task for feature 292 started.
# Task for feature 293 started.
# Task for feature 294 started.
# Task for feature 295 started.
# Task for feature 296 started.
# Task for feature 297 started.
# Task for feature 298 started.
# Task for feature 299 started.
# Task for feature 300 started.
# Task for feature 301 started.
# Task for feature 302 started.
# Task for feature 303 started.
# Task for feature 304 started.
# Task for feature 305 started.
# Task for feature 306 started.
# Task for feature 307 started.
# Task for feature 308 started.
# Task for feature 309 started.
# Task for feature 310 started.
# Task for feature 311 started.
# Task for feature 312 started.
# Task for feature 313 started.
# Task for feature 314 started.
# Task for feature 315 started.
# Task for feature 316 started.
# Task for feature 317 started.
# Task for feature 318 started.
# Task for feature 319 started.
# Task for feature 320 started.
# Task for feature 321 started.
# Task for feature 322 started.
# Task for feature 323 started.
# Task for feature 324 started.
# Task for feature 325 started.
# Task for feature 326 started.
# Task for feature 327 started.
# Task for feature 328 started.
# Task for feature 329 started.
# Task for feature 330 started.
# Task for feature 331 started.
# Task for feature 332 started.
# Task for feature 333 started.
# Task for feature 334 started.
# Task for feature 335 started.
# Task for feature 336 started.
# Task for feature 337 started.
# Task for feature 338 started.
# Task for feature 339 started.
# Task for feature 340 started.
# Task for feature 341 started.
# Task for feature 342 started.
# Task for feature 343 started.
# Task for feature 344 started.
# Task for feature 345 started.
# Task for feature 346 started.
# Task for feature 347 started.
# Task for feature 348 started.
# Task for feature 349 started.
# Task for feature 350 started.
# Task for feature 351 started.
# Task for feature 352 started.
# Task for feature 353 started.
# Task for feature 354 started.
# Task for feature 355 started.
# Task for feature 356 started.
# Task for feature 357 started.
# Task for feature 358 started.
# Task for feature 359 started.
# Task for feature 360 started.
# Task for feature 361 started.
# Task for feature 362 started.
# Task for feature 363 started.
# Task for feature 364 started.
# Task for feature 365 started.
# Task for feature 366 started.
# Task for feature 367 started.
# Task for feature 368 started.
# Task for feature 369 started.
# Task for feature 370 started.
# Task for feature 371 started.
# Task for feature 372 started.
# Task for feature 373 started.
# Task for feature 374 started.
# Task for feature 375 started.
# Task for feature 376 started.
# Task for feature 377 started.
# Task for feature 378 started.
# Task for feature 379 started.
# Task for feature 380 started.
# Task for feature 381 started.
# Task for feature 382 started.
# Task for feature 383 started.
# Task for feature 384 started.
# Task for feature 385 started.
# Task for feature 386 started.
# Task for feature 387 started.
# Task for feature 388 started.
# Task for feature 389 started.
# Task for feature 390 started.
# Task for feature 391 started.
# Task for feature 392 started.
# Task for feature 393 started.
# Task for feature 394 started.
# Task for feature 395 started.
# Task for feature 396 started.
# Task for feature 397 started.
# Task for feature 398 started.
# Task for feature 399 started.
# Task for feature 400 started.
# Task for feature 401 started.
# Task for feature 402 started.
# Task for feature 403 started.
# Task for feature 404 started.
# Task for feature 405 started.
# Task for feature 406 started.
# Task for feature 407 started.
# Task for feature 408 started.
# Task for feature 409 started.
# Task for feature 410 started.
# Task for feature 411 started.
# Task for feature 412 started.
# Task for feature 413 started.
# Task for feature 414 started.
# Task for feature 415 started.
# Task for feature 416 started.
# Task for feature 417 started.
# Task for feature 418 started.
# Task for feature 419 started.
# Task for feature 420 started.
# Task for feature 421 started.
# Task for feature 422 started.
# Task for feature 423 started.
# Task for feature 424 started.
# Task for feature 425 started.
# Task for feature 426 started.
# Task for feature 427 started.
# Task for feature 428 started.
# Task for feature 429 started.
# Task for feature 430 started.
# Task for feature 431 started.
# Task for feature 432 started.
# Task for feature 433 started.
# Task for feature 434 started.
# Task for feature 435 started.
# Task for feature 436 started.
# Task for feature 437 started.
# Task for feature 438 started.
# Task for feature 439 started.
# Task for feature 440 started.
# Task for feature 441 started.
# Task for feature 442 started.
# Task for feature 443 started.
# Task for feature 444 started.
# Task for feature 445 started.
# Task for feature 446 started.
# Task for feature 447 started.
# Task for feature 448 started.
# Task for feature 449 started.
# Task for feature 450 started.
# Task for feature 451 started.
# Task for feature 452 started.
# Task for feature 453 started.
# Task for feature 454 started.
# Task for feature 455 started.
# Task for feature 456 started.
# Task for feature 457 started.
# Task for feature 458 started.
# Task for feature 459 started.
# Task for feature 460 started.
# Task for feature 461 started.
# Task for feature 462 started.
# Task for feature 463 started.
# Task for feature 464 started.
# Task for feature 465 started.
# Task for feature 466 started.
# Task for feature 467 started.
# Task for feature 468 started.
# Task for feature 469 started.
# Task for feature 470 started.
# Task for feature 471 started.
# Task for feature 472 started.
# Task for feature 473 started.
# Task for feature 474 started.
# Task for feature 475 started.
# Task for feature 476 started.
# Task for feature 477 started.
# Task for feature 478 started.
# Task for feature 479 started.
# Task for feature 480 started.
# Task for feature 481 started.
# Task for feature 482 started.
# Task for feature 483 started.
# Task for feature 484 started.
# Task for feature 485 started.
# Task for feature 486 started.
# Task for feature 487 started.
# Task for feature 488 started.
# Task for feature 489 started.
# Task for feature 490 started.
# Task for feature 491 started.
# Task for feature 492 started.
# Task for feature 493 started.
# Task for feature 494 started.
# Task for feature 495 started.
# Task for feature 496 started.
# Task for feature 497 started.
# Task for feature 498 started.
# Exporting images: 100%|██████████| 1/1 [03:44<00:00, 224.97s/it]
# Task for feature 499 started.
# All export tasks initiated.

# %% [markdown]
# # Aragon

# %%
output_folder = "ar_dl_final"
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
for i in tqdm(range(len(start_dates)), desc='Exporting images'):

    start_date = start_dates[i]
    end_date = end_dates[i]
    label = labels[i]


    # Load Sentinel-2 image collection.
    dataset = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED') \
    .filterDate(start_date, end_date) \
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20)) \
    .map(maskS2clouds) \
    .select(['B4', 'B3', 'B2', 'B8'])

    # Define the area of interest.
    geometry = ee.FeatureCollection('projects/ee-huijuanli/assets/random_squares_ar')

    # Select the first image from the collection.
    imageToExport = dataset.median() 

    # Get the list of features in the collection.
    features = geometry.getInfo()['features']

    # Loop through each feature and submit an export task.
    for index, feature in enumerate(features):
        featureGeometry = ee.Feature(feature).geometry()
        imageToExportClipped = imageToExport.clip(featureGeometry)
        
        task = ee.batch.Export.image.toDrive(
            image=imageToExportClipped,
            description=f'Sentinel2_Image_Export_{index}_{label}',
            scale=10,
            folder=f'{output_folder}',
            region=featureGeometry,
            fileFormat='GeoTIFF',
            crs='EPSG:25831', 
            formatOptions={
                'cloudOptimized': True
            }
        )
        task.start()
        print(f'Task for feature {index} started.')

    print('All export tasks initiated.')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Exporting images:   0%|          | 0/1 [00:00<?, ?it/s]
# Task for feature 0 started.
# Task for feature 1 started.
# Task for feature 2 started.
# Task for feature 3 started.
# Task for feature 4 started.
# Task for feature 5 started.
# Task for feature 6 started.
# Task for feature 7 started.
# Task for feature 8 started.
# Task for feature 9 started.
# Task for feature 10 started.
# Task for feature 11 started.
# Task for feature 12 started.
# Task for feature 13 started.
# Task for feature 14 started.
# Task for feature 15 started.
# Task for feature 16 started.
# Task for feature 17 started.
# Task for feature 18 started.
# Task for feature 19 started.
# Task for feature 20 started.
# Task for feature 21 started.
# Task for feature 22 started.
# Task for feature 23 started.
# Task for feature 24 started.
# Task for feature 25 started.
# Task for feature 26 started.
# Task for feature 27 started.
# Task for feature 28 started.
# Task for feature 29 started.
# Task for feature 30 started.
# Task for feature 31 started.
# Task for feature 32 started.
# Task for feature 33 started.
# Task for feature 34 started.
# Task for feature 35 started.
# Task for feature 36 started.
# Task for feature 37 started.
# Task for feature 38 started.
# Task for feature 39 started.
# Task for feature 40 started.
# Task for feature 41 started.
# Task for feature 42 started.
# Task for feature 43 started.
# Task for feature 44 started.
# Task for feature 45 started.
# Task for feature 46 started.
# Task for feature 47 started.
# Task for feature 48 started.
# Task for feature 49 started.
# Task for feature 50 started.
# Task for feature 51 started.
# Task for feature 52 started.
# Task for feature 53 started.
# Task for feature 54 started.
# Task for feature 55 started.
# Task for feature 56 started.
# Task for feature 57 started.
# Task for feature 58 started.
# Task for feature 59 started.
# Task for feature 60 started.
# Task for feature 61 started.
# Task for feature 62 started.
# Task for feature 63 started.
# Task for feature 64 started.
# Task for feature 65 started.
# Task for feature 66 started.
# Task for feature 67 started.
# Task for feature 68 started.
# Task for feature 69 started.
# Task for feature 70 started.
# Task for feature 71 started.
# Task for feature 72 started.
# Task for feature 73 started.
# Task for feature 74 started.
# Task for feature 75 started.
# Task for feature 76 started.
# Task for feature 77 started.
# Task for feature 78 started.
# Task for feature 79 started.
# Task for feature 80 started.
# Task for feature 81 started.
# Task for feature 82 started.
# Task for feature 83 started.
# Task for feature 84 started.
# Task for feature 85 started.
# Task for feature 86 started.
# Task for feature 87 started.
# Task for feature 88 started.
# Task for feature 89 started.
# Task for feature 90 started.
# Task for feature 91 started.
# Task for feature 92 started.
# Task for feature 93 started.
# Task for feature 94 started.
# Task for feature 95 started.
# Task for feature 96 started.
# Task for feature 97 started.
# Task for feature 98 started.
# Task for feature 99 started.
# Task for feature 100 started.
# Task for feature 101 started.
# Task for feature 102 started.
# Task for feature 103 started.
# Task for feature 104 started.
# Task for feature 105 started.
# Task for feature 106 started.
# Task for feature 107 started.
# Task for feature 108 started.
# Task for feature 109 started.
# Task for feature 110 started.
# Task for feature 111 started.
# Task for feature 112 started.
# Task for feature 113 started.
# Task for feature 114 started.
# Task for feature 115 started.
# Task for feature 116 started.
# Task for feature 117 started.
# Task for feature 118 started.
# Task for feature 119 started.
# Task for feature 120 started.
# Task for feature 121 started.
# Task for feature 122 started.
# Task for feature 123 started.
# Task for feature 124 started.
# Task for feature 125 started.
# Task for feature 126 started.
# Task for feature 127 started.
# Task for feature 128 started.
# Task for feature 129 started.
# Task for feature 130 started.
# Task for feature 131 started.
# Task for feature 132 started.
# Task for feature 133 started.
# Task for feature 134 started.
# Task for feature 135 started.
# Task for feature 136 started.
# Task for feature 137 started.
# Task for feature 138 started.
# Task for feature 139 started.
# Task for feature 140 started.
# Task for feature 141 started.
# Task for feature 142 started.
# Task for feature 143 started.
# Task for feature 144 started.
# Task for feature 145 started.
# Task for feature 146 started.
# Task for feature 147 started.
# Task for feature 148 started.
# Task for feature 149 started.
# Task for feature 150 started.
# Task for feature 151 started.
# Task for feature 152 started.
# Task for feature 153 started.
# Task for feature 154 started.
# Task for feature 155 started.
# Task for feature 156 started.
# Task for feature 157 started.
# Task for feature 158 started.
# Task for feature 159 started.
# Task for feature 160 started.
# Task for feature 161 started.
# Task for feature 162 started.
# Task for feature 163 started.
# Task for feature 164 started.
# Task for feature 165 started.
# Task for feature 166 started.
# Task for feature 167 started.
# Task for feature 168 started.
# Task for feature 169 started.
# Task for feature 170 started.
# Task for feature 171 started.
# Task for feature 172 started.
# Task for feature 173 started.
# Task for feature 174 started.
# Task for feature 175 started.
# Task for feature 176 started.
# Task for feature 177 started.
# Task for feature 178 started.
# Task for feature 179 started.
# Task for feature 180 started.
# Task for feature 181 started.
# Task for feature 182 started.
# Task for feature 183 started.
# Task for feature 184 started.
# Task for feature 185 started.
# Task for feature 186 started.
# Task for feature 187 started.
# Task for feature 188 started.
# Task for feature 189 started.
# Task for feature 190 started.
# Task for feature 191 started.
# Task for feature 192 started.
# Task for feature 193 started.
# Task for feature 194 started.
# Task for feature 195 started.
# Task for feature 196 started.
# Task for feature 197 started.
# Task for feature 198 started.
# Task for feature 199 started.
# Task for feature 200 started.
# Task for feature 201 started.
# Task for feature 202 started.
# Task for feature 203 started.
# Task for feature 204 started.
# Task for feature 205 started.
# Task for feature 206 started.
# Task for feature 207 started.
# Task for feature 208 started.
# Task for feature 209 started.
# Task for feature 210 started.
# Task for feature 211 started.
# Task for feature 212 started.
# Task for feature 213 started.
# Task for feature 214 started.
# Task for feature 215 started.
# Task for feature 216 started.
# Task for feature 217 started.
# Task for feature 218 started.
# Task for feature 219 started.
# Task for feature 220 started.
# Task for feature 221 started.
# Task for feature 222 started.
# Task for feature 223 started.
# Task for feature 224 started.
# Task for feature 225 started.
# Task for feature 226 started.
# Task for feature 227 started.
# Task for feature 228 started.
# Task for feature 229 started.
# Task for feature 230 started.
# Task for feature 231 started.
# Task for feature 232 started.
# Task for feature 233 started.
# Task for feature 234 started.
# Task for feature 235 started.
# Task for feature 236 started.
# Task for feature 237 started.
# Task for feature 238 started.
# Task for feature 239 started.
# Task for feature 240 started.
# Task for feature 241 started.
# Task for feature 242 started.
# Task for feature 243 started.
# Task for feature 244 started.
# Task for feature 245 started.
# Task for feature 246 started.
# Task for feature 247 started.
# Task for feature 248 started.
# Task for feature 249 started.
# Task for feature 250 started.
# Task for feature 251 started.
# Task for feature 252 started.
# Task for feature 253 started.
# Task for feature 254 started.
# Task for feature 255 started.
# Task for feature 256 started.
# Task for feature 257 started.
# Task for feature 258 started.
# Task for feature 259 started.
# Task for feature 260 started.
# Task for feature 261 started.
# Task for feature 262 started.
# Task for feature 263 started.
# Task for feature 264 started.
# Task for feature 265 started.
# Task for feature 266 started.
# Task for feature 267 started.
# Task for feature 268 started.
# Task for feature 269 started.
# Task for feature 270 started.
# Task for feature 271 started.
# Task for feature 272 started.
# Task for feature 273 started.
# Task for feature 274 started.
# Task for feature 275 started.
# Task for feature 276 started.
# Task for feature 277 started.
# Task for feature 278 started.
# Task for feature 279 started.
# Task for feature 280 started.
# Task for feature 281 started.
# Task for feature 282 started.
# Task for feature 283 started.
# Task for feature 284 started.
# Task for feature 285 started.
# Task for feature 286 started.
# Task for feature 287 started.
# Task for feature 288 started.
# Task for feature 289 started.
# Task for feature 290 started.
# Task for feature 291 started.
# Task for feature 292 started.
# Task for feature 293 started.
# Task for feature 294 started.
# Task for feature 295 started.
# Task for feature 296 started.
# Task for feature 297 started.
# Task for feature 298 started.
# Task for feature 299 started.
# Task for feature 300 started.
# Task for feature 301 started.
# Task for feature 302 started.
# Task for feature 303 started.
# Task for feature 304 started.
# Task for feature 305 started.
# Task for feature 306 started.
# Task for feature 307 started.
# Task for feature 308 started.
# Task for feature 309 started.
# Task for feature 310 started.
# Task for feature 311 started.
# Task for feature 312 started.
# Task for feature 313 started.
# Task for feature 314 started.
# Task for feature 315 started.
# Task for feature 316 started.
# Task for feature 317 started.
# Task for feature 318 started.
# Task for feature 319 started.
# Task for feature 320 started.
# Task for feature 321 started.
# Task for feature 322 started.
# Task for feature 323 started.
# Task for feature 324 started.
# Task for feature 325 started.
# Task for feature 326 started.
# Task for feature 327 started.
# Task for feature 328 started.
# Task for feature 329 started.
# Task for feature 330 started.
# Task for feature 331 started.
# Task for feature 332 started.
# Task for feature 333 started.
# Task for feature 334 started.
# Task for feature 335 started.
# Task for feature 336 started.
# Task for feature 337 started.
# Task for feature 338 started.
# Task for feature 339 started.
# Task for feature 340 started.
# Task for feature 341 started.
# Task for feature 342 started.
# Task for feature 343 started.
# Task for feature 344 started.
# Task for feature 345 started.
# Task for feature 346 started.
# Task for feature 347 started.
# Task for feature 348 started.
# Task for feature 349 started.
# Task for feature 350 started.
# Task for feature 351 started.
# Task for feature 352 started.
# Task for feature 353 started.
# Task for feature 354 started.
# Task for feature 355 started.
# Task for feature 356 started.
# Task for feature 357 started.
# Task for feature 358 started.
# Task for feature 359 started.
# Task for feature 360 started.
# Task for feature 361 started.
# Task for feature 362 started.
# Task for feature 363 started.
# Task for feature 364 started.
# Task for feature 365 started.
# Task for feature 366 started.
# Task for feature 367 started.
# Task for feature 368 started.
# Task for feature 369 started.
# Task for feature 370 started.
# Task for feature 371 started.
# Task for feature 372 started.
# Task for feature 373 started.
# Task for feature 374 started.
# Task for feature 375 started.
# Task for feature 376 started.
# Task for feature 377 started.
# Task for feature 378 started.
# Task for feature 379 started.
# Task for feature 380 started.
# Task for feature 381 started.
# Task for feature 382 started.
# Task for feature 383 started.
# Task for feature 384 started.
# Task for feature 385 started.
# Task for feature 386 started.
# Task for feature 387 started.
# Task for feature 388 started.
# Task for feature 389 started.
# Task for feature 390 started.
# Task for feature 391 started.
# Task for feature 392 started.
# Task for feature 393 started.
# Task for feature 394 started.
# Task for feature 395 started.
# Task for feature 396 started.
# Task for feature 397 started.
# Task for feature 398 started.
# Task for feature 399 started.
# Task for feature 400 started.
# Task for feature 401 started.
# Task for feature 402 started.
# Task for feature 403 started.
# Task for feature 404 started.
# Task for feature 405 started.
# Task for feature 406 started.
# Task for feature 407 started.
# Task for feature 408 started.
# Task for feature 409 started.
# Task for feature 410 started.
# Task for feature 411 started.
# Task for feature 412 started.
# Task for feature 413 started.
# Task for feature 414 started.
# Task for feature 415 started.
# Task for feature 416 started.
# Task for feature 417 started.
# Task for feature 418 started.
# Task for feature 419 started.
# Task for feature 420 started.
# Task for feature 421 started.
# Task for feature 422 started.
# Task for feature 423 started.
# Task for feature 424 started.
# Task for feature 425 started.
# Task for feature 426 started.
# Task for feature 427 started.
# Task for feature 428 started.
# Task for feature 429 started.
# Task for feature 430 started.
# Task for feature 431 started.
# Task for feature 432 started.
# Task for feature 433 started.
# Task for feature 434 started.
# Task for feature 435 started.
# Task for feature 436 started.
# Task for feature 437 started.
# Task for feature 438 started.
# Task for feature 439 started.
# Task for feature 440 started.
# Task for feature 441 started.
# Task for feature 442 started.
# Task for feature 443 started.
# Task for feature 444 started.
# Task for feature 445 started.
# Task for feature 446 started.
# Task for feature 447 started.
# Task for feature 448 started.
# Task for feature 449 started.
# Task for feature 450 started.
# Task for feature 451 started.
# Task for feature 452 started.
# Task for feature 453 started.
# Task for feature 454 started.
# Task for feature 455 started.
# Task for feature 456 started.
# Task for feature 457 started.
# Task for feature 458 started.
# Task for feature 459 started.
# Task for feature 460 started.
# Task for feature 461 started.
# Task for feature 462 started.
# Task for feature 463 started.
# Task for feature 464 started.
# Task for feature 465 started.
# Task for feature 466 started.
# Task for feature 467 started.
# Task for feature 468 started.
# Task for feature 469 started.
# Task for feature 470 started.
# Task for feature 471 started.
# Task for feature 472 started.
# Task for feature 473 started.
# Task for feature 474 started.
# Task for feature 475 started.
# Task for feature 476 started.
# Task for feature 477 started.
# Task for feature 478 started.
# Task for feature 479 started.
# Task for feature 480 started.
# Task for feature 481 started.
# Task for feature 482 started.
# Task for feature 483 started.
# Task for feature 484 started.
# Task for feature 485 started.
# Task for feature 486 started.
# Task for feature 487 started.
# Task for feature 488 started.
# Task for feature 489 started.
# Task for feature 490 started.
# Task for feature 491 started.
# Task for feature 492 started.
# Task for feature 493 started.
# Task for feature 494 started.
# Task for feature 495 started.
# Task for feature 496 started.
# Task for feature 497 started.
# Task for feature 498 started.
# Exporting images: 100%|██████████| 1/1 [02:56<00:00, 176.60s/it]
# Task for feature 499 started.
# All export tasks initiated.
